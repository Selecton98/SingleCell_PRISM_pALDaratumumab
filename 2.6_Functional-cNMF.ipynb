# %% [markdown]
# # 2.6 Visualization of functional enrichment results (2)
#
# Author: Xuezhu Sunny Wang
#
# ## Dataset 📊
#
# - Gene lists of gene expression programs from cNMF analysis
#
# ## Steps overview 📒
# - Run GO BP enrichment for gene lists
# - Plot the results

# %%
marker_table <- read.csv("plasma_cnmf_3_topgenes_withoutIG_k=13.csv")
marker_table
# Out:
#     X  X1          X2       X3         X4         X5         X6
# 1    0 DHRS9       CD19     MS4A1      CFHR1      AC233755.1 PPP1R14A
# 2    1 NEB         RNASE6   CCL3       AC246787.2 LY6K       CST6
# 3    2 PTP4A3      CD27     FGF7       FAM30A     GPR15      SPON2
# 4    3 AL353753.1  HLA-DPA1 LAPTM5     CTSW       SLC2A5     CGREF1
# 5    4 NUDT12      HLA-DQB1 CPVL       SLC22A17   DDIT4      TMEM119
# 6    5 ISLR        HLA-DRB5 ALOX5AP    JCHAIN     AKAP12     CLDN3
# 7    6 LINC01088   CD79A    BTG1       SPINK2     CTSW       TRPM4
# 8    7 HIST1H1C    HLA-DRB1 ZFP36L2    RBP1       ID3        OBP2A
# 9    8 MT-ND5      HLA-DMA  CCL4       CADPS2     GRASP      PHACTR3
# 10   9 DEPP1       TPST2    PHACTR1    SLIT3      TMSB4X     AC026369.3
# 11  10 IFI27       ISG20    CCND1      ASS1       TMEM176A   LINC01405
# 12  11 LAG3        CD74     MYADM      NT5E       ID2        LAPTM4B
# 13  12 RPL36A      XBP1     TSC22D3    PSAT1      TUBB2A     MSLN
# ...

# %%
marker_table$X<-NULL

# %%
library(clusterProfiler)
library(org.Hs.eg.db)
library(enrichplot)
library(dplyr)

# Store all enrichment results
all_marker_enrichment <- list()

# Loop through each gene signature (column)
for (marker_name in colnames(marker_table)) {
  cat("Processing marker set:", marker_name, "\n")
  
  # Get the gene list from the column, remove NA
  geneList <- na.omit(marker_table[[marker_name]])
  
  # Skip empty sets
  if (length(geneList) < 3) {
    cat("Too few genes for enrichment in", marker_name, "\n")
    next
  }

  # Convert to Entrez ID
  gene.df <- bitr(geneList, fromType = "SYMBOL",
                  toType = "ENTREZID",
                  OrgDb = org.Hs.eg.db)

  if (nrow(gene.df) < 3) {
    cat("No valid Entrez IDs found for", marker_name, "\n")
    next
  }

  # Run enrichment
  ego <- enrichGO(gene = gene.df$ENTREZID,
                  OrgDb = org.Hs.eg.db,
                  keyType = "ENTREZID",
                  ont = "BP",
                  pvalueCutoff = 0.05,
                  qvalueCutoff = 0.2,
                  pAdjustMethod = "BH",
                  readable = TRUE)

  # Store results
  if (!is.null(ego) && nrow(as.data.frame(ego)) > 0) {
    ego_df <- as.data.frame(ego)
    ego_df$marker <- marker_name
    all_marker_enrichment[[marker_name]] <- ego_df
  } else {
    cat("No significant enrichment for", marker_name, "\n")
  }
}

# Combine all results into one table
combined_marker_enrichment <- bind_rows(all_marker_enrichment)

# Save to file
write.csv(combined_marker_enrichment, "GO_BP_enrichment_marker_sets-cnmf.csv", row.names = FALSE)

# Preview
head(combined_marker_enrichment)
# Out:
# Registered S3 methods overwritten by 'treeio':
#   method              from
#   MRCA.phylo          tidytree
#   MRCA.treedata       tidytree
#   Nnode.treedata      tidytree
#   Ntip.treedata       tidytree
#   ancestor.phylo      tidytree
#   ancestor.treedata   tidytree
#   child.phylo         tidytree
#   child.treedata      tidytree
#   full_join.phylo     tidytree
#   full_join.treedata  tidytree
#   groupClade.phylo    tidytree
#   groupClade.treedata tidytree
#   groupOTU.phylo      tidytree
#   groupOTU.treedata   tidytree
#   inner_join.phylo    tidytree
#   inner_join.treedata tidytree
#   is.rooted.treedata  tidytree
#   nodeid.phylo        tidytree
#   nodeid.treedata     tidytree
#   nodelab.phylo       tidytree
#   nodelab.treedata    tidytree
#   offspring.phylo     tidytree
#   offspring.treedata  tidytree
#   parent.phylo        tidytree
#   parent.treedata     tidytree
#   root.treedata       tidytree
#   rootnode.phylo      tidytree
# ...

# %%
# Load packages
library(ggplot2)
library(readr)
library(dplyr)

df<-read.csv('GO_BP_enrichment_marker_sets-cnmf.csv')
df$Descrtiption<-paste(df$ID,df$Description,sep=':')
df
# Out:
#      ID
# 1    GO:0002181
# 2    GO:0042273
# 3    GO:0043086
# 4    GO:0042254
# 5    GO:1901796
# 6    GO:0072331
# 7    GO:2000630
# 8    GO:2000116
# 9    GO:0052548
# 10   GO:0000470
# 11   GO:1901798
# 12   GO:0051346
# 13   GO:0052547
# 14   GO:0019886
# 15   GO:0002495
# 16   GO:0002504
# 17   GO:0002478
# 18   GO:0002399
# 19   GO:0002503
# 20   GO:0019884
# 21   GO:0019882
# 22   GO:0002396
# 23   GO:0002501
# 24   GO:0048002
# 25   GO:0050870
# 26   GO:0051251
# 27   GO:0050853
# 28   GO:1903039
# 29   GO:0042113
# 30   GO:0050864
# ⋮    ⋮
# 1810 GO:0061844
# 1811 GO:0050731
# 1812 GO:0001911
# 1813 GO:0002407
# 1814 GO:0002438
# 1815 GO:0098581
# 1816 GO:1901623
# 1817 GO:1905523
# 1818 GO:1903039
# 1819 GO:0050867
# 1820 GO:0007204
# 1821 GO:0010758
# 1822 GO:0030194
# 1823 GO:0031664
# 1824 GO:0071624
# 1825 GO:1900048
# 1826 GO:0032635
# 1827 GO:0032675
# 1828 GO:0045824
# 1829 GO:0002418
# 1830 GO:0002710
# 1831 GO:0010971
# 1832 GO:0031342
# 1833 GO:0039531
# ...

# %%
# Load packages
library(ggplot2)
library(readr)
library(dplyr)

df<-read.csv('GO_BP_enrichment_marker_sets-cnmf-selected.csv')
df$Descrtiption<-paste(df$ID,df$Description,sep=':')
df
# Out:
#    ID
# 1  GO:0002181
# 2  GO:0042273
# 3  GO:1901796
# 4  GO:0052548
# 5  GO:2000116
# 6  GO:0050871
# 7  GO:0032527
# 8  GO:0042100
# 9  GO:1901657
# 10 GO:0045579
# 11 GO:0002503
# 12 GO:0071356
# 13 GO:0038066
# 14 GO:0050729
# 15 GO:0071347
# 16 GO:0035710
# 17 GO:0042113
# 18 GO:0034976
# 19 GO:0006986
# 20 GO:0035966
# 21 GO:0030970
# 22 GO:0030968
# 23 GO:0036503
# 24 GO:0009070
# 25 GO:0008207
# 26 GO:0098742
# 27 GO:0071383
# 28 GO:2000146
# 29 GO:0007599
# 30 GO:0097501
# 31 GO:0061687
# 32 GO:0009636
# 33 GO:0034976
# 34 GO:0097193
# 35 GO:1902903
# 36 GO:0051346
# 37 GO:0032677
# 38 GO:0032637
# 39 GO:0042100
# 40 GO:0032613
# 41 GO:0032653
# 42 GO:0097242
# 43 GO:1901224
# 44 GO:0043123
# 45 GO:0031055
# 46 GO:1902751
# 47 GO:1902412
# 48 GO:0007095
# 49 GO:0070507
# 50 GO:0016446
# 51 GO:0031398
# 52 GO:1903320
#    Description
# 1  cytoplasmic translation
# 2  ribosomal large subunit biogenesis
# 3  regulation of signal transduction by p53 class mediator
# ...

# %%
table(df$marker)
# Out:
#  X1 X11  X2  X3  X4  X6  X7  X9
#   5   8   6   6   7   5   7   8

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X1'),]

options(repr.plot.height = 5, repr.plot.width = 10)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_1 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# Loading required package: viridisLite
# plot without title

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X11'),]

options(repr.plot.height = 5, repr.plot.width = 12)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_11 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# plot without title

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X2'),]

options(repr.plot.height = 5, repr.plot.width = 9.5)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_2 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# plot without title

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X3'),]

options(repr.plot.height = 5, repr.plot.width = 10)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_3 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# plot without title

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X4'),]

options(repr.plot.height = 5, repr.plot.width = 10)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_4 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# plot without title

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X6'),]

options(repr.plot.height = 5, repr.plot.width = 10)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_6 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# plot without title

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X7'),]

options(repr.plot.height = 5, repr.plot.width = 10)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_7 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# plot without title

# %%
library(viridis)

# Optional: keep top 20 enriched terms based on FDR
df_filtered <- df[which(df$marker == 'X9'),]

options(repr.plot.height = 5, repr.plot.width = 10)

# Create the bubble plot
ggplot(df_filtered, aes(x = Count, y = reorder(Description, Count))) +
  geom_point(aes(size = Count, color = p.adjust)) +
  scale_color_viridis_c(name = "p.adjust", option = "plasma", direction = -1) +
  scale_size(range = c(3, 12), name = "Gene Count") +
  theme_bw() +
  labs(
    x = "Gene count",
    y = "",
    title = "GP_9 Bubble Plot"
  ) +
  theme(
    axis.text.y = element_text(size = 10),
    plot.margin = margin(t = 5, r = 5, b = 5, l = 40, unit = "pt")
  )
# Out:
# plot without title

# %%
library(dplyr)
library(tidyr)
library(stringr)
library(forcats)
library(ggplot2)
library(viridis)

top_n <- 15

markers <- c("X1","X2","X4","X6","X11",'X3',"X7")

# base R
df_filtered <- df[df$marker %in% markers, ]

# (optional) keep these markers in this order for plotting
df_filtered$marker <- factor(df_filtered$marker, levels = markers)


df_top <- df_filtered %>%
  group_by(marker) %>%
  slice_min(p.adjust, n = top_n, with_ties = FALSE) %>%
  ungroup() %>%
  mutate(
    term = str_wrap(Description, width = 50)
  )

# Order terms globally by their best (lowest) p.adjust so important ones appear centered
term_order <- df_top %>%
  group_by(term) %>%
  summarize(best_p = suppressWarnings(min(p.adjust, na.rm = TRUE))) %>%
  arrange(best_p) %>%
  pull(term)

df_top <- df_top %>%
  mutate(
    term = factor(term, levels = rev(term_order)),        # y order
    marker = factor(marker)                               # x order (customize if you want)
  )

options(repr.plot.height = 12, repr.plot.width = 12)
ggplot(df_top, aes(x = marker, y = term)) +
  geom_point(aes(size = Count, color = p.adjust), alpha = 0.9) +
  scale_color_gradient(high = "#d9ecd3",low = "#2c3991", name = "FDR") +
  scale_size(range = c(2.5, 10), name = "Gene Count") +
  labs(x = "Group", y = NULL, title = "GO Enrichment Across Groups") +
  theme_bw() +
  theme(
    axis.text.y = element_text(size = 9),
    axis.text.x = element_text(size = 10, angle = 45, hjust = 1),
    plot.margin = margin(t = 5, r = 10, b = 5, l = 10)
  )
# Out:
# plot without title
